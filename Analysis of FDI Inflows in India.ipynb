# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_inflows = pd.read_csv(r"C:\Users\HP\Downloads\world_investment_report_2022_selected_fdi_flows.csv")
df_inflows
# Out:
#     Year         India
# 0   1990    236.690000
# 1   1991     75.000000
# 2   1992    252.000000
# 3   1993    532.000000
# 4   1994    974.000000
# 5   1995   2151.000000
# 6   1996   2525.000000
# 7   1997   3619.000000
# 8   1998   2633.000000
# 9   1999   2168.000000
# 10  2000   3587.989747
# 11  2001   5477.637624
# 12  2002   5629.671078
# 13  2003   4321.076437
# 14  2004   5777.807200
# 15  2005   7621.768707
# 16  2006  20327.763920
# 17  2007  25349.891770
# 18  2008  47102.417250
# 19  2009  35633.939490
# 20  2010  27417.076640
# 21  2011  36190.456030
# 22  2012  24195.766920
# 23  2013  28199.421980
# 24  2014  34582.096810
# 25  2015  44064.101720
# 26  2016  44480.571750
# 27  2017  39903.840400
# 28  2018  42156.193370
# 29  2019  50558.331000
# 30  2020  64072.238490
# 31  2021  44762.679640
# 32  2022  49354.611950

# %%
df_inflows['India'].mean()
# Out:
# 21391.91030069697

# %%
df_inflows['India'].median()
# Out:
# 20327.76392

# %%
df_inflows['India'].max()
# Out:
# 64072.23849

# %%
df_inflows['India'].min()
# Out:
# 75.0

# %%
df_inflows['India'].std()
# Out:
# 19916.55194020653

# %%
plt.plot(df_inflows['Year'], df_inflows['India'])
plt.xlabel("Year")
plt.ylabel("Millions of Dollars")
plt.title("FDI inflows in India between 1990 and 2022")
plt.text(1990, 60000, "Source: UNCTAD", fontsize=6)
plt.show()

# %%
df_Percentage_of_total_world_Value = pd.read_csv(r"C:\Users\HP\Downloads\US.FdiFlowsStock_20231115_131724.csv")
df_Percentage_of_total_world_Value
# Out:
#    Economy_Label  Year  Percentage_of_total_world_Value
# 0          India  1990                            0.116
# 1          India  1991                            0.049
# 2          India  1992                            0.153
# 3          India  1993                            0.239
# 4          India  1994                            0.381
# 5          India  1995                            0.623
# 6          India  1996                            0.643
# 7          India  1997                            0.753
# 8          India  1998                            0.386
# 9          India  1999                            0.201
# 10         India  2000                            0.264
# 11         India  2001                            0.709
# 12         India  2002                            0.954
# 13         India  2003                            0.786
# 14         India  2004                            0.826
# 15         India  2005                            0.799
# ...

# %%
print(df_Percentage_of_total_world_Value['Percentage_of_total_world_Value'].mean())
print(df_Percentage_of_total_world_Value['Percentage_of_total_world_Value'].median())
print(df_Percentage_of_total_world_Value['Percentage_of_total_world_Value'].max())
print(df_Percentage_of_total_world_Value['Percentage_of_total_world_Value'].min())
print(df_Percentage_of_total_world_Value['Percentage_of_total_world_Value'].std())
# Out:
# 1.6179393939393938
# 1.33
# 6.66
# 0.049
# 1.423302759855443

# %%
plt.plot(df_Percentage_of_total_world_Value['Year'], df_Percentage_of_total_world_Value['Percentage_of_total_world_Value'])
plt.xlabel("Year")
plt.ylabel("%")
plt.title("FDI inflows as % of total world Value")
plt.text(1990, 6, "Source: UNCTAD", fontsize=6)
plt.show()

# %%
df_Percentage_of_gdp = pd.read_csv(r"C:\Users\HP\Downloads\US.FdiFlowsStock_20231115_132248.csv")
df_Percentage_of_gdp
# Out:
#    Economy_Label  Year  Percentage_of_Gross_Domestic_Product_Value
# 0          India  1990                                        0.07
# 1          India  1991                                        0.03
# 2          India  1992                                        0.09
# 3          India  1993                                        0.19
# 4          India  1994                                        0.30
# 5          India  1995                                        0.58
# 6          India  1996                                        0.64
# 7          India  1997                                        0.85
# 8          India  1998                                        0.61
# 9          India  1999                                        0.47
# 10         India  2000                                        0.75
# 11         India  2001                                        1.12
# 12         India  2002                                        1.10
# ...

# %%
print(df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value'].mean())
print(df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value'].median())
print(df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value'].max())
print(df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value'].min())
print(df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value'].std())
# Out:
# 1.2745454545454546
# 1.3
# 3.72
# 0.03
# 0.8424780817219034

# %%
plt.plot(df_Percentage_of_gdp['Year'], df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value'])
plt.xlabel("Year")
plt.ylabel("%")
plt.title("FDI inflows as % of Gross Domestic Product")
plt.text(1990, max(df_Percentage_of_gdp['Percentage_of_Gross_Domestic_Product_Value']), "Source: UNCTAD", fontsize=6)
plt.show()

# %%
df_fdi_year_sector = pd.read_csv(r"C:\Users\HP\Downloads\RS_Session_256_AU_3392_1.csv")
df_fdi_year_sector
# Out:
#           Sl No                                             Sector  \
# 0             1                           Metallurgical Industries
# 1             2                                             Mining
# 2             3                                              Power
# 3             4                            Non-conventional Energy
# 4             5                            Petroleum & Natural Gas
# 5             6                Boilers and Steam Generating Plants
# 6             7     Prime Mover (Other Than Electrical Generators)
# 7             8                              Electrical Equipments
# 8             9                       Computer Software & Hardware
# 9            10                                        Electronics
# 10           11                                 Telecommunications
# 11           12  Information & Broadcasting (including Print Me...
# 12           13                                Automobile Industry
# ...

# %%
df_fdi_year_sector[]
